# %%
corpus="""hello everyone i am vishva. i intrested to learn AI    
"""

# %%
print(corpus)
# Out:
# hello everyone i am vishva. i intrested to learn AI

# %%
# tokenization 
## para -> sentance
from nltk.tokenize import sent_tokenize
sent_tokenize(corpus)
# Out:
# ['hello everyone i am vishva.', 'i intrested to learn AI']

# %%
sen1=sent_tokenize(corpus)
sen1[0]
# Out:
# 'hello everyone i am vishva.'

# %%
## para -->words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['hello',
#  'everyone',
#  'i',
#  'am',
#  'vishva',
#  '.',
#  'i',
#  'intrested',
#  'to',
#  'learn',
#  'AI']

# %% [markdown]
# Text preprocessing

# %%
## stemming
# the stemming means it cutting a word down to its basic /root like form by removing prefixes or suffixes
# fro example (palying ,plyed,plays) --> play

# %%
words=['eating','eats','eaten','writing','writes','programming','programs','history','finally','finalize']

# %%
# proterstemmer
from nltk.stem import PorterStemmer
stemming=PorterStemmer()

# %%
for word in words:
  print(word+'----->'+stemming.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalize----->final

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem('sitting')
# Out:
# 'sit'

# %%
from nltk.stem import RegexpStemmer
stemming=RegexpStemmer('ing$')
print(stemming.stem('playing'))
print(stemming.stem('writing'))
print(stemming.stem('dancing'))
# Out:
# play
# writ
# danc

# %%
#SnowballStemmer 
# is a stemming algorithm in NLTK that removes prefixes/suffixes from words to convert them into a common root-like form.
# It is an improved version of the Porter Stemmer approach and supports multiple languages.

# %%
from nltk.stem import SnowballStemmer
snowball=SnowballStemmer('english')
for word in words:
  print(word+'----->'+snowball.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalize----->final

# %%
#RegexpStemmer
#     ↓
#You make the rules
#     ↓
#"Remove ing"

#PorterStemmer
#    ↓
#Predefined English stemming rules

#SnowballStemmer
#     ↓
#Improved/flexible stemming framework
#     ↓
#Supports multiple languages

# %%
stemming.stem('fairly'),stemming.stem('sportingly')
# Out:
# ('fairly', 'sportingly')

# %%
snowball.stem('fairly'),snowball.stem('sportingly')
# Out:
# ('fair', 'sport')

# %%
stemming.stem('goes')
# Out:
# 'goes'

# %%
snowball.stem('goes')
# Out:
# 'goe'

# %%
#lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
lemmatizer.lemmatize('goes')
# Out:
# 'go'

# %%
lemmatizer.lemmatize('history')
# Out:
# 'history'

# %%
'''
pos-noun-n,
verb-v,
adjective-a,
adverb-r
'''
# Out:
# '\npos-noun-n,\nverb-v,\nadjective-a,\n#adverb-r\n'

# %%
lemmatizer.lemmatize('goes',pos='a')
# Out:
# 'goes'

# %%
lemmatizer.lemmatize('goes',pos='r')
# Out:
# 'goes'

# %%
for word in words:
  print(word,'--->',lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating ---> eat
# eats ---> eat
# eaten ---> eat
# writing ---> write
# writes ---> write
# programming ---> program
# programs ---> program
# history ---> history
# finally ---> finally
# finalize ---> finalize

# %%
lemmatizer.lemmatize('fairly')
# Out:
# 'fairly'
